# %%
from jupyter_server_titiler.api import test

print(test())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 3
#       1 from jupyter_server_titiler.api import test
# ----> 3 print(test())
#
# File ~/Projects/geojupyter/hackathon-prototype/jupyter_server_titiler/api.py:59, in test()
#      55 def test() -> Dataset | DataArray:
#      56     ds = rioxarray.open_rasterio(
#      57         "https://s2downloads.eox.at/demo/EOxCloudless/2020/rgbnir/s2cloudless2020-16bits_sinlge-file_z0-4.tif"
#      58     )
# ---> 59     return explore(ds)
#
# File ~/Projects/geojupyter/hackathon-prototype/jupyter_server_titiler/api.py:46, in explore(*args)
#      43     app.include_router(tiler_factory.router)
#      45     import uvicorn
# ---> 46     uvicorn.run(app=app, host="127.0.0.1", port=8080, log_level="info")
#      47     # return app, xarray_id_lookup
#      48
#      49 # Display a widget
# ...
